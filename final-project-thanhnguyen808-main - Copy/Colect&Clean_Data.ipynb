# %%
import os
import pandas as pd
import numpy as np
import ast

# %%
df = pd.read_csv('Data/DataMTP.Fan.csv')
raw_df = df[0:11]
df = df.loc[:, [ "post_id", "post_text", "time", "comments", "comments_full", "reaction_count", "shares", "reactions"]]
df = df.fillna(0.0) # lọc
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   post_id         86 non-null     object
#  1   post_text       86 non-null     object
#  2   time            86 non-null     object
#  3   comments        86 non-null     int64
#  4   comments_full   86 non-null     object
#  5   reaction_count  86 non-null     int64
#  6   shares          86 non-null     int64
#  7   reactions       86 non-null     object
# dtypes: int64(3), object(5)
# memory usage: 5.5+ KB

# %%
FANPAGE_LINK ="MTP.Fan.Data"
FOLDER_PATH = "Data/"

path=FOLDER_PATH + FANPAGE_LINK + ".csv"
df.to_csv(path, index=False)
print(path)
# Out:
# Data/MTP.Fan.Data.csv

# %%
df
# Out:
#                                               post_id  \
# 0   pfbid0365FumFYrvxgmKJGJzbvd9mmRQyb38GKVPf3pkYy...
# 1   pfbid0GMYfP2ZYrSTGqcrCSkFyQTZm3nv3Cn26tdAviYYU...
# 2   pfbid0Ptc6oLei2WFwSWqY3tXhrfQgQSD6RMBKfZCzCKwb...
# 3   pfbid038GGZxxJkdBDqPUXwVuERDEs2vaW6ZC567hXa71v...
# 4   pfbid071RnaDhQGJ4VfFv6rCBpgFYvZcDrof6UzxmJjhLx...
# ..                                                ...
# 81  pfbid0kekqbxMkEM1jFsn2DdZLFXB3SjdBTyvzN9RdLUgc...
# 82  pfbid04A5q1P2ciFCUpaKhEqN3tCwe1JrmbHyCfgjooJKZ...
# 83  pfbid02wHFG4nwMSndXCTfsW4RXHrydpZwSJhiBfUqKw1n...
# 84  pfbid02Rp7DjohLct2YNnpMUptvirLpwT8q8WFVG5J1KXF...
# 85  pfbid0iTRBFeLXkXr7MkAQn6hyAjRySbgYLapxzDViaKCd...
#
#                                             post_text                 time  \
# 0   MAKING MY WAY will be officially released at 0...  2023-04-25 20:00:00
# 1                                                  …🤫  2023-04-23 20:00:00
# 2                     Quick stroll on Rodeo Drive 🍦✨😌  2023-03-15 20:00:00
# ...
