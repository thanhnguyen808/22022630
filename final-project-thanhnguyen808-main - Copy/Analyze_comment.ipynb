# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
raw_df = pd.read_csv('Data/DataMTP.Fan.csv')
raw_df = raw_df.loc[:, [ "post_id", "post_text", "time", "comments", "comments_full", "reaction_count", "shares", "reactions"]]
raw_df = raw_df.dropna(how='any',axis=0)

# %%
res=[]
for post in raw_df:
    if len(raw_df['comments_full']) > 0:
      print(raw_df['comments_full'])
      cmt = '\n'.join([comment['comment_text'] for comment in raw_df['comments_full'] ])
      res.append(cmt)
print(len(res))
print(res)
# Out:
# 0     [{'comment_id': '888002016286382', 'comment_ur...
# 1     [{'comment_id': '884306766628209', 'comment_ur...
# 2     [{'comment_id': '6641114912590518', 'comment_u...
# 3     [{'comment_id': '188537340958297', 'comment_ur...
# 4     [{'comment_id': '2337859259936195', 'comment_u...
# 5     [{'comment_id': '3581671468747825', 'comment_u...
# 6     [{'comment_id': '309161898500671', 'comment_ur...
# 7     [{'comment_id': '858729259304442', 'comment_ur...
# 8     [{'comment_id': '983812312909085', 'comment_ur...
# 9     [{'comment_id': '708824707938702', 'comment_ur...
# 10    [{'comment_id': '1315190615775398', 'comment_u...
# 11    [{'comment_id': '335135432300344', 'comment_ur...
# 12    [{'comment_id': '1358053524794772', 'comment_u...
# 13    [{'comment_id': '1030173515093721', 'comment_u...
# Name: comments_full, dtype: object
# ---------------------------------------------------------------------------
# ...

# %%
raw_df = raw_df.reset_index(inplace = False)
raw_df["index"] = raw_df["index"] + 1

# %%
raw_df.plot(kind = "bar", x = "index", y = "comments", figsize = (50, 20));

# %%
sum(raw_df.comments)
# Out:
# 132600

# %%
raw_df.comments.median()
# Out:
# 9550.0

# %%
raw_df.index[raw_df['comments'] == min(raw_df.comments)]
# Out:
# Int64Index([11], dtype='int64')

# %%
raw_df.plot(kind = "line", x = "index", y = "comments");
